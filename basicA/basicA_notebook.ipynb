# %% [markdown]
# # Basic_A
#
# 3,4,8,9. linelar kütüphane oluşturulmak istendiği zaman silinmeli

# %%
import sys
sys.path.insert(0, "/Users/emirsener/Desktop/ts-clustering")

from simclstr.clusterer import perform_clustering, read_time_series
from simclstr.plotting import plot_clusters

import os
model_path_vensim = os.path.expanduser('~/Desktop/SESDYN_Basic_A/Basic_A_Vensim.xlsx')

read_data_vensim = read_time_series(model_path_vensim)

clustering_results_vensim = perform_clustering(read_data_vensim, cMethod='maxclust', cValue = 6, plotDendrogram=True, transform='normalize')

plot_clusters(clustering_results_vensim[1], 'pattern_dtw')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[6], line 12
#       8 model_path_vensim = os.path.expanduser('~/Desktop/SESDYN_Basic_A/Basic_A_Vensim.xlsx')
#      10 read_data_vensim = read_time_series(model_path_vensim)
# ---> 12 clustering_results_vensim = perform_clustering(read_data_vensim, cMethod='maxclust', cValue = 6, plotDendrogram=True, transform='standardize')
#      14 plot_clusters(clustering_results_vensim[1], 'pattern_dtw')
#
# TypeError: perform_clustering() got an unexpected keyword argument 'transform'

# %%
model_path_stellaff = os.path.expanduser('~/Desktop/SESDYN_Basic_A/Basic_A_StellaFF.xlsx')

read_data_stellaff = read_time_series(model_path_stellaff)

clustering_results_stellaff = perform_clustering(read_data_stellaff, cMethod='maxclust', cValue = 5, plotDendrogram=True, transform='normalize')

plot_clusters(clustering_results_stellaff[1], 'pattern_dtw')

# %%
model_path_stella2 = os.path.expanduser('~/Desktop/SESDYN_Basic_A/Basic_A_Stella2.xlsx')

read_data_stella2 = read_time_series(model_path_stella2)

clustering_results_stella2 = perform_clustering(read_data_stella2, cMethod='maxclust', cValue = 5, plotDendrogram=True, transform='normalize')

plot_clusters(clustering_results_stella2[1], 'pattern_dtw')
